# %% [markdown]
# <a href="https://colab.research.google.com/github/NumeroQuadro/ml-advanced-lab-1/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная 1 - 10 баллов (дедлайн 07.03.2024)
# Нужно сгенерировать 3 cлучайных нелинейных регрессии (разные функции!). Для обоих
# частей задания зафиксировать размерности 2-3х линейных слоев, их активации, функцию
# потери, lr и оптимизатор, кол-во эпох.
# Первая часть задания: протестировать модель только с батчнормом с 3 разными
# размерами батча.
#
# Вторая часть: протестировать модель с лучшим размером батча из первой части
# 1. без дропаута и без батчнорма,
# 2. только с батчнормом без дропаута,
# 3. только с дропаутом без батчнорма,
# 4. и с батчнормом и с дропаутом.
# Визуализировать результаты (график).
# В пару предложений записать выводы.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

np.random.seed(42)

def generate_nonlinear_data(func_num, n_samples=1000):
    # изначальный диапазон [-5, 5]
    X = np.random.uniform(-5, 5, (n_samples, 1))

    if func_num == 1:
        y = np.sin(X) + 0.3 * np.random.randn(n_samples, 1)
    elif func_num == 2:
        y = 0.5 * X**4 - 2 * X**3 + 6 * X**2 + X + 0.5 * np.random.randn(n_samples, 1)
    elif func_num == 3:
        y = np.exp(-0.5 * X**2) + 0.2 * np.random.randn(n_samples, 1)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    return X_train, X_test, y_train, y_test, X, y

# x, if x > 0; 0
def relu(x):
    return np.maximum(0, x)

# derivative of relu: 1, if x > 0; 0
def relu_derivative(x):
    return np.where(x > 0, 1, 0)

class NeuralNetwork:
    def __init__(self, input_size, hidden_sizes, use_dropout=False, use_batch_norm=False, dropout_rate=0.2):
        self.input_size = input_size
        self.hidden_sizes = hidden_sizes
        self.use_dropout = use_dropout  # флаг юзаем дропаут регуляризацию или нет
        self.use_batch_norm = use_batch_norm  # флаг надо ли использовать батч-нормализацию
        self.dropout_rate = dropout_rate  # вероятность выброса нейронов в dropout (потом в формуле будет 1-dropout_rate)

        self.weights = []
        self.biases = []
        self.batch_norm_params = []

        layer_sizes = [input_size] + hidden_sizes + [1]
        # цикл по слоям в нейросети
        for i in range(len(layer_sizes) - 1):
            # инициализация весов (с xavier инициализацией)
            w = np.random.randn(layer_sizes[i], layer_sizes[i+1]) * np.sqrt(2 / (layer_sizes[i] + layer_sizes[i+1]))
            b = np.zeros((1, layer_sizes[i+1]))
            self.weights.append(w)
            self.biases.append(b)

            # параметры батч-нормализации
            if i < len(layer_sizes) - 2 and use_batch_norm:
                self.batch_norm_params.append({
                    'gamma': np.ones((1, layer_sizes[i+1])),  # Масштабирующий коэффициент
                    'beta': np.zeros((1, layer_sizes[i+1])),  # Сдвиг
                    'running_mean': np.zeros((1, layer_sizes[i+1])),  # Скользящее среднее
                    'running_var': np.ones((1, layer_sizes[i+1])),  # Скользящая дисперсия
                })
            else:
                self.batch_norm_params.append(None)

    def batch_normalization_forward(self, x, layer_idx, training=True):
        if not self.use_batch_norm or self.batch_norm_params[layer_idx] is None:
            return x

        params = self.batch_norm_params[layer_idx]

        if training:
            # считаем среднее и дисперсию по батчу
            batch_mean = np.mean(x, axis=0, keepdims=True)
            batch_var = np.var(x, axis=0, keepdims=True) + 1e-8

            params['running_mean'] = 0.9 * params['running_mean'] + 0.1 * batch_mean
            params['running_var'] = 0.9 * params['running_var'] + 0.1 * batch_var

            x_normalized = (x - batch_mean) / np.sqrt(batch_var) # нормализация

            params['batch_mean'] = batch_mean
            params['batch_var'] = batch_var
            params['x_normalized'] = x_normalized
            params['x'] = x
        else:
            # Во время тестирования используем скользящие среднее и дисперсию
            x_normalized = (x - params['running_mean']) / np.sqrt(params['running_var']) # z-масштабирование

        # Применяем масштабирование и сдвиг
        out = params['gamma'] * x_normalized + params['beta']
        return out

    def dropout_forward(self, x, training=True):
        if not self.use_dropout or not training:
            return x, None

        # маска чтобы оставить только (1-dropout_rate) процентов значений
        mask = np.random.binomial(1, 1 - self.dropout_rate, size=x.shape) / (1 - self.dropout_rate)
        out = x * mask # юзаем маску чтобы отсеять некоторые значения
        return out, mask

    def forward(self, X, training=True):
        activations = [X]
        z_values = []
        dropout_masks = []

        # цикл по слоям
        for i in range(len(self.weights)):
            # считаем лин комб z = X * W + b
            z = np.dot(activations[-1], self.weights[i]) + self.biases[i]
            z_values.append(z)

            if i < len(self.weights) - 1:  # для скрытых слоёв
                z = self.batch_normalization_forward(z, i, training)  # normalizing batch
                a = relu(z)
                a, mask = self.dropout_forward(a, training)
                dropout_masks.append(mask)
            else:
                a = z

            activations.append(a)

        cache = (activations, z_values, dropout_masks)
        return activations[-1], cache

    def backward(self, y, cache, learning_rate, clip_value=1.0):
        activations, z_values, dropout_masks = cache
        m = y.shape[0]  # Размер батча

        dw = [np.zeros_like(w) for w in self.weights]
        db = [np.zeros_like(b) for b in self.biases]

        delta = activations[-1] - y # ошибка на output слое (произв mse)

        for i in reversed(range(len(self.weights))):
            dw[i] = np.dot(activations[i].T, delta) / m
            db[i] = np.sum(delta, axis=0, keepdims=True) / m

            if i > 0:  # Для скрытых слоёв
                delta = np.dot(delta, self.weights[i].T)

                if self.use_dropout and i-1 < len(dropout_masks) and dropout_masks[i-1] is not None:
                    delta = delta * dropout_masks[i-1]

                delta = delta * relu_derivative(z_values[i-1])

                if np.any(np.isnan(delta)) or np.any(np.isinf(delta)):
                    delta = np.nan_to_num(delta, nan=0.0, posinf=0.0, neginf=0.0)

            dw[i] = np.clip(dw[i], -clip_value, clip_value)
            db[i] = np.clip(db[i], -clip_value, clip_value)

        for i in range(len(self.weights)):
            self.weights[i] -= learning_rate * dw[i]
            self.biases[i] -= learning_rate * db[i]

    def train(self, X_train, y_train, X_val, y_val, batch_size=32, epochs=200, learning_rate=0.01, clip_value=1.0, verbose=True):
        m = X_train.shape[0]  # колво обучающих примеров
        train_losses = []
        val_losses = []

        # Цикл по эпохам
        for epoch in range(epochs):
            indices = np.random.permutation(m)
            X_shuffled = X_train[indices]
            y_shuffled = y_train[indices]

            # Обучение по мини-батчам
            for i in range(0, m, batch_size):
                end = min(i + batch_size, m)
                X_batch = X_shuffled[i:end] # шаффлим для лучших резов
                y_batch = y_shuffled[i:end]

                # Прямой проход на батче
                y_pred, cache = self.forward(X_batch, training=True)
                # Обратный проход для обновления весов
                self.backward(y_batch, cache, learning_rate, clip_value)

            train_pred, _ = self.forward(X_train, training=False)
            val_pred, _ = self.forward(X_val, training=False)
            train_loss = np.mean((train_pred - y_train) ** 2)
            val_loss = np.mean((val_pred - y_val) ** 2)

            train_losses.append(train_loss)
            val_losses.append(val_loss)

            if verbose and (epoch + 1) % 20 == 0:
                print(f'Эпоха [{epoch+1}/{epochs}], Потери на обучении: {train_loss:.4f}, Потери на валидации: {val_loss:.4f}')

        return train_losses, val_losses

def test_batch_sizes(X_train, X_test, y_train, y_test, batch_sizes=[16, 32, 64], learning_rates=[0.001, 0.01, 0.1], epochs_list=[100, 200]):
    print("\n===== Часть 1: Тестирование разных размеров батча с перебором параметров =====")
    results = []

    for batch_size in batch_sizes:
        for lr in learning_rates:
            for epochs in epochs_list:
                print(f"\nТестирование: batch_size={batch_size}, lr={lr}, epochs={epochs}")
                model = NeuralNetwork(
                    input_size=1,
                    hidden_sizes=[64, 32, 16],
                    use_dropout=False,
                    use_batch_norm=True
                )
                train_losses, test_losses = model.train(
                    X_train, y_train, X_test, y_test,
                    batch_size=batch_size, epochs=epochs, learning_rate=lr, clip_value=5.0, verbose=False
                )
                y_pred, _ = model.forward(X_test, training=False)
                final_test_loss = np.mean((y_pred - y_test) ** 2)
                result = {
                    "batch_size": batch_size,
                    "learning_rate": lr,
                    "epochs": epochs,
                    "final_test_loss": final_test_loss,
                    "train_losses": train_losses,
                    "test_losses": test_losses,
                    "model": model
                }
                results.append(result)
                print(f"Результат: batch_size={batch_size}, lr={lr}, epochs={epochs}, потери на тесте={final_test_loss:.6f}")

    best_result = min(results, key=lambda x: x['final_test_loss'])
    best_batch_size = best_result['batch_size']
    best_lr = best_result['learning_rate']
    best_epochs = best_result['epochs']
    print(f"\nЛучшие параметры для части 1: batch_size={best_batch_size}, lr={best_lr}, epochs={best_epochs} с потерями на тесте: {best_result['final_test_loss']:.6f}")
    return results, (best_batch_size, best_lr, best_epochs)

def test_regularization_configs(X_train, X_test, y_train, y_test, best_batch_size, best_lr, best_epochs, dropout_rates=[0.1, 0.2, 0.3]):
    print(f"\n===== Часть 2: Тестирование конфигураций регуляризации с batch_size={best_batch_size}, lr={best_lr}, epochs={best_epochs} =====")
    configurations = [
        {"name": "Без Dropout, Без BatchNorm", "dropout": False, "batch_norm": False},
        {"name": "С BatchNorm, Без Dropout", "dropout": False, "batch_norm": True},
        {"name": "С Dropout, Без BatchNorm", "dropout": True, "batch_norm": False},
        {"name": "С Dropout, С BatchNorm", "dropout": True, "batch_norm": True}
    ]
    results = []

    for config in configurations:
        dropout_rates_to_test = [0] if not config["dropout"] else dropout_rates
        for dropout_rate in dropout_rates_to_test:
            print(f"\nТестирование: {config['name']}, dropout_rate={dropout_rate}")
            model = NeuralNetwork(
                input_size=1,
                hidden_sizes=[64, 32, 16],
                use_dropout=config["dropout"],
                use_batch_norm=config["batch_norm"],
                dropout_rate=dropout_rate
            )
            train_losses, test_losses = model.train(
                X_train, y_train, X_test, y_test,
                batch_size=best_batch_size, epochs=best_epochs, learning_rate=best_lr, clip_value=5.0, verbose=False
            )
            y_pred, _ = model.forward(X_test, training=False)
            final_test_loss = np.mean((y_pred - y_test) ** 2)
            result = {
                "configuration": config["name"],
                "dropout_rate": dropout_rate,
                "final_test_loss": final_test_loss,
                "train_losses": train_losses,
                "test_losses": test_losses,
                "model": model
            }
            results.append(result)
            print(f"Результат: {config['name']}, dropout_rate={dropout_rate}, потери на тесте={final_test_loss:.6f}")

    best_result = min(results, key=lambda x: x['final_test_loss'])
    best_config = best_result['configuration']
    best_dropout_rate = best_result['dropout_rate']
    print(f"\nЛучшие параметры для части 2: config={best_config}, dropout_rate={best_dropout_rate} с потерями на тесте: {best_result['final_test_loss']:.6f}")
    return results, (best_config, best_dropout_rate)

def visualize_results(batch_size_results, reg_config_results, X, y, func_num):
    plt.figure(figsize=(15, 10))

    plt.subplot(2, 2, 1)
    for result in batch_size_results:
        plt.plot(result['test_losses'], label=f"Batch={result['batch_size']}, lr={result['learning_rate']}, epochs={result['epochs']}")
    plt.title(f'Часть 1: Кривые потерь на тесте для разных размеров батча - Функция {func_num}')
    plt.xlabel('Эпохи')
    plt.ylabel('MSE Потери')
    plt.legend()

    plt.subplot(2, 2, 2)
    for result in reg_config_results:
        plt.plot(result['test_losses'], label=f"{result['configuration']}, dropout_rate={result['dropout_rate']}")
    plt.title(f'Часть 2: Кривые потерь на тесте для разных конфигураций - Функция {func_num}')
    plt.xlabel('Эпохи')
    plt.ylabel('MSE Потери')
    plt.legend()

    plt.subplot(2, 2, 3)
    best_model_result = min(reg_config_results, key=lambda x: x['final_test_loss'])
    best_model = best_model_result['model']
    sorted_indices = np.argsort(X.ravel())
    X_sorted = X[sorted_indices]
    y_sorted = y[sorted_indices]
    predictions, _ = best_model.forward(X_sorted, training=False)
    plt.scatter(X, y, s=5, alpha=0.5, label='Реальные данные')
    plt.plot(X_sorted, predictions, 'r-', linewidth=2, label='Предсказания лучшей модели')
    plt.title(f'Предсказания лучшей модели - Функция {func_num}')
    plt.xlabel('X')
    plt.ylabel('y')
    plt.legend()

    plt.subplot(2, 2, 4)
    batch_labels = [f"Batch={r['batch_size']}, lr={r['learning_rate']}, epochs={r['epochs']}" for r in batch_size_results]
    batch_losses = [r['final_test_loss'] for r in batch_size_results]
    config_labels = [f"{r['configuration']}, dr={r['dropout_rate']}" for r in reg_config_results]
    config_losses = [r['final_test_loss'] for r in reg_config_results]
    all_labels = batch_labels + config_labels
    all_losses = batch_losses + config_losses
    bars = plt.bar(range(len(all_labels)), all_losses, color=['blue']*len(batch_labels) + ['green']*len(config_labels))
    plt.xticks(range(len(all_labels)), all_labels, rotation=45, ha='right')
    plt.title(f'Финальные потери на тесте - Функция {func_num}')
    plt.ylabel('MSE Потери')
    best_loss = min(all_losses)
    plt.axhline(y=best_loss, color='r', linestyle='--')
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.001, f'{height:.4f}', ha='center', va='bottom', rotation=45)

    plt.tight_layout()
    plt.savefig(f'function_{func_num}_results.png')
    plt.show()

def main():
    all_conclusions = []

    for func_num in range(1, 4):
        print(f"\n\n===== Тестирование функции {func_num} =====")
        X_train, X_test, y_train, y_test, X, y = generate_nonlinear_data(func_num)

        # Часть 1: Тестирование с перебором параметров
        batch_results, (best_batch_size, best_lr, best_epochs) = test_batch_sizes(X_train, X_test, y_train, y_test)

        # Часть 2: Тестирование конфигураций с лучшими параметрами
        reg_results, (best_config, best_dropout_rate) = test_regularization_configs(
            X_train, X_test, y_train, y_test, best_batch_size, best_lr, best_epochs
        )

        # Визуализация результатов
        visualize_results(batch_results, reg_results, X, y, func_num)

        # Сохраняем выводы
        all_conclusions.append({
            "function": func_num,
            "best_batch_size": best_batch_size,
            "best_learning_rate": best_lr,
            "best_epochs": best_epochs,
            "best_configuration": best_config,
            "best_dropout_rate": best_dropout_rate
        })

    # Общие выводы
    print("\n===== Общие выводы =====")
    for c in all_conclusions:
        print(f"Функция {c['function']}:")
        print(f"  Лучший размер батча: {c['best_batch_size']}")
        print(f"  Лучшая скорость обучения (lr): {c['best_learning_rate']}")
        print(f"  Лучшее количество эпох: {c['best_epochs']}")
        print(f"  Лучшая конфигурация: {c['best_configuration']}")
        print(f"  Лучший dropout rate: {c['best_dropout_rate']}")
        print("")

    # Краткие выводы в пару предложений
    print("Выводы:")
    print("Модель показала различные оптимальные параметры для каждой функции, при этом batch normalization и dropout влияют на стабильность и точность предсказаний.")
    print("Перебор параметров позволил улучшить производительность сети, особенно для сложных нелинейных зависимостей.")

if __name__ == "__main__":
    main()
# Out:
# ===== Тестирование функции 1 =====
#
# ===== Часть 1: Тестирование разных размеров батча с перебором параметров =====
#
# Тестирование: batch_size=16, lr=0.001, epochs=100
# Результат: batch_size=16, lr=0.001, epochs=100, потери на тесте=0.180353
#
# Тестирование: batch_size=16, lr=0.001, epochs=200
# Результат: batch_size=16, lr=0.001, epochs=200, потери на тесте=0.153263
#
# Тестирование: batch_size=16, lr=0.01, epochs=100
# Результат: batch_size=16, lr=0.01, epochs=100, потери на тесте=0.128396
#
# Тестирование: batch_size=16, lr=0.01, epochs=200
# Результат: batch_size=16, lr=0.01, epochs=200, потери на тесте=0.180106
#
# Тестирование: batch_size=16, lr=0.1, epochs=100
# Результат: batch_size=16, lr=0.1, epochs=100, потери на тесте=0.274204
#
# Тестирование: batch_size=16, lr=0.1, epochs=200
# Результат: batch_size=16, lr=0.1, epochs=200, потери на тесте=0.139851
#
# Тестирование: batch_size=32, lr=0.001, epochs=100
# Результат: batch_size=32, lr=0.001, epochs=100, потери на тесте=0.971023
#
# Тестирование: batch_size=32, lr=0.001, epochs=200
# Результат: batch_size=32, lr=0.001, epochs=200, потери на тесте=0.111761
#
# Тестирование: batch_size=32, lr=0.01, epochs=100
# Результат: batch_size=32, lr=0.01, epochs=100, потери на тесте=0.144304
#
# Тестирование: batch_size=32, lr=0.01, epochs=200
# Результат: batch_size=32, lr=0.01, epochs=200, потери на тесте=0.125039
#
# Тестирование: batch_size=32, lr=0.1, epochs=100
# Результат: batch_size=32, lr=0.1, epochs=100, потери на тесте=0.342630
#
# Тестирование: batch_size=32, lr=0.1, epochs=200
# Результат: batch_size=32, lr=0.1, epochs=200, потери на тесте=0.118037
#
# Тестирование: batch_size=64, lr=0.001, epochs=100
# Результат: batch_size=64, lr=0.001, epochs=100, потери на тесте=0.223953
#
# Тестирование: batch_size=64, lr=0.001, epochs=200
# Результат: batch_size=64, lr=0.001, epochs=200, потери на тесте=0.162941
#
# Тестирование: batch_size=64, lr=0.01, epochs=100
# Результат: batch_size=64, lr=0.01, epochs=100, потери на тесте=0.129485
#
# Тестирование: batch_size=64, lr=0.01, epochs=200
# Результат: batch_size=64, lr=0.01, epochs=200, потери на тесте=0.107261
#
# Тестирование: batch_size=64, lr=0.1, epochs=100
# Результат: batch_size=64, lr=0.1, epochs=100, потери на тесте=0.253111
#
# Тестирование: batch_size=64, lr=0.1, epochs=200
# Результат: batch_size=64, lr=0.1, epochs=200, потери на тесте=0.270177
#
# Лучшие параметры для части 1: batch_size=64, lr=0.01, epochs=200 с потерями на тесте: 0.107261
#
# ===== Часть 2: Тестирование конфигураций регуляризации с batch_size=64, lr=0.01, epochs=200 =====
#
# Тестирование: Без Dropout, Без BatchNorm, dropout_rate=0
# Результат: Без Dropout, Без BatchNorm, dropout_rate=0, потери на тесте=0.090626
#
# Тестирование: С BatchNorm, Без Dropout, dropout_rate=0
# Результат: С BatchNorm, Без Dropout, dropout_rate=0, потери на тесте=0.164422
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.1
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.1, потери на тесте=0.106572
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.2
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.2, потери на тесте=0.144965
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.3
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.3, потери на тесте=0.192933
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.1
# Результат: С Dropout, С BatchNorm, dropout_rate=0.1, потери на тесте=0.261777
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.2
# Результат: С Dropout, С BatchNorm, dropout_rate=0.2, потери на тесте=0.278591
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.3
# Результат: С Dropout, С BatchNorm, dropout_rate=0.3, потери на тесте=0.436934
#
# Лучшие параметры для части 2: config=Без Dropout, Без BatchNorm, dropout_rate=0 с потерями на тесте: 0.090626
# ===== Тестирование функции 2 =====
#
# ===== Часть 1: Тестирование разных размеров батча с перебором параметров =====
#
# Тестирование: batch_size=16, lr=0.001, epochs=100
# Результат: batch_size=16, lr=0.001, epochs=100, потери на тесте=919.737670
#
# Тестирование: batch_size=16, lr=0.001, epochs=200
# Результат: batch_size=16, lr=0.001, epochs=200, потери на тесте=1222.310115
#
# Тестирование: batch_size=16, lr=0.01, epochs=100
# Результат: batch_size=16, lr=0.01, epochs=100, потери на тесте=1057.592428
#
# Тестирование: batch_size=16, lr=0.01, epochs=200
# Результат: batch_size=16, lr=0.01, epochs=200, потери на тесте=369.301650
#
# Тестирование: batch_size=16, lr=0.1, epochs=100
# Результат: batch_size=16, lr=0.1, epochs=100, потери на тесте=1112.273620
#
# Тестирование: batch_size=16, lr=0.1, epochs=200
# Результат: batch_size=16, lr=0.1, epochs=200, потери на тесте=2077.988796
#
# Тестирование: batch_size=32, lr=0.001, epochs=100
# Результат: batch_size=32, lr=0.001, epochs=100, потери на тесте=2207.502056
#
# Тестирование: batch_size=32, lr=0.001, epochs=200
# Результат: batch_size=32, lr=0.001, epochs=200, потери на тесте=808.476055
#
# Тестирование: batch_size=32, lr=0.01, epochs=100
# Результат: batch_size=32, lr=0.01, epochs=100, потери на тесте=566.793811
#
# Тестирование: batch_size=32, lr=0.01, epochs=200
# Результат: batch_size=32, lr=0.01, epochs=200, потери на тесте=549.670810
#
# Тестирование: batch_size=32, lr=0.1, epochs=100
# Результат: batch_size=32, lr=0.1, epochs=100, потери на тесте=668.824502
#
# Тестирование: batch_size=32, lr=0.1, epochs=200
# Результат: batch_size=32, lr=0.1, epochs=200, потери на тесте=667.952016
#
# Тестирование: batch_size=64, lr=0.001, epochs=100
# Результат: batch_size=64, lr=0.001, epochs=100, потери на тесте=10597.910582
#
# Тестирование: batch_size=64, lr=0.001, epochs=200
# Результат: batch_size=64, lr=0.001, epochs=200, потери на тесте=1163.573264
#
# Тестирование: batch_size=64, lr=0.01, epochs=100
# Результат: batch_size=64, lr=0.01, epochs=100, потери на тесте=365.283248
#
# Тестирование: batch_size=64, lr=0.01, epochs=200
# Результат: batch_size=64, lr=0.01, epochs=200, потери на тесте=391.276331
#
# Тестирование: batch_size=64, lr=0.1, epochs=100
# Результат: batch_size=64, lr=0.1, epochs=100, потери на тесте=537.361974
#
# Тестирование: batch_size=64, lr=0.1, epochs=200
# Результат: batch_size=64, lr=0.1, epochs=200, потери на тесте=412.565682
#
# Лучшие параметры для части 1: batch_size=64, lr=0.01, epochs=100 с потерями на тесте: 365.283248
#
# ===== Часть 2: Тестирование конфигураций регуляризации с batch_size=64, lr=0.01, epochs=100 =====
#
# Тестирование: Без Dropout, Без BatchNorm, dropout_rate=0
# Результат: Без Dropout, Без BatchNorm, dropout_rate=0, потери на тесте=2733.322326
#
# Тестирование: С BatchNorm, Без Dropout, dropout_rate=0
# Результат: С BatchNorm, Без Dropout, dropout_rate=0, потери на тесте=605.471664
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.1
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.1, потери на тесте=7077.971540
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.2
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.2, потери на тесте=3418.654729
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.3
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.3, потери на тесте=889.580679
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.1
# Результат: С Dropout, С BatchNorm, dropout_rate=0.1, потери на тесте=764.246088
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.2
# Результат: С Dropout, С BatchNorm, dropout_rate=0.2, потери на тесте=825.341971
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.3
# Результат: С Dropout, С BatchNorm, dropout_rate=0.3, потери на тесте=1020.747014
#
# Лучшие параметры для части 2: config=С BatchNorm, Без Dropout, dropout_rate=0 с потерями на тесте: 605.471664
# ===== Тестирование функции 3 =====
#
# ===== Часть 1: Тестирование разных размеров батча с перебором параметров =====
#
# Тестирование: batch_size=16, lr=0.001, epochs=100
# Результат: batch_size=16, lr=0.001, epochs=100, потери на тесте=0.068973
#
# Тестирование: batch_size=16, lr=0.001, epochs=200
# Результат: batch_size=16, lr=0.001, epochs=200, потери на тесте=0.052687
#
# Тестирование: batch_size=16, lr=0.01, epochs=100
# Результат: batch_size=16, lr=0.01, epochs=100, потери на тесте=0.055753
#
# Тестирование: batch_size=16, lr=0.01, epochs=200
# Результат: batch_size=16, lr=0.01, epochs=200, потери на тесте=0.052469
#
# Тестирование: batch_size=16, lr=0.1, epochs=100
# Результат: batch_size=16, lr=0.1, epochs=100, потери на тесте=0.052152
#
# Тестирование: batch_size=16, lr=0.1, epochs=200
# Результат: batch_size=16, lr=0.1, epochs=200, потери на тесте=0.045875
#
# Тестирование: batch_size=32, lr=0.001, epochs=100
# Результат: batch_size=32, lr=0.001, epochs=100, потери на тесте=0.061317
#
# Тестирование: batch_size=32, lr=0.001, epochs=200
# Результат: batch_size=32, lr=0.001, epochs=200, потери на тесте=0.054882
#
# Тестирование: batch_size=32, lr=0.01, epochs=100
# Результат: batch_size=32, lr=0.01, epochs=100, потери на тесте=0.046311
#
# Тестирование: batch_size=32, lr=0.01, epochs=200
# Результат: batch_size=32, lr=0.01, epochs=200, потери на тесте=0.042180
#
# Тестирование: batch_size=32, lr=0.1, epochs=100
# Результат: batch_size=32, lr=0.1, epochs=100, потери на тесте=0.054220
#
# Тестирование: batch_size=32, lr=0.1, epochs=200
# Результат: batch_size=32, lr=0.1, epochs=200, потери на тесте=0.056277
#
# Тестирование: batch_size=64, lr=0.001, epochs=100
# Результат: batch_size=64, lr=0.001, epochs=100, потери на тесте=0.108777
#
# Тестирование: batch_size=64, lr=0.001, epochs=200
# Результат: batch_size=64, lr=0.001, epochs=200, потери на тесте=0.048534
#
# Тестирование: batch_size=64, lr=0.01, epochs=100
# Результат: batch_size=64, lr=0.01, epochs=100, потери на тесте=0.045179
#
# Тестирование: batch_size=64, lr=0.01, epochs=200
# Результат: batch_size=64, lr=0.01, epochs=200, потери на тесте=0.054849
#
# Тестирование: batch_size=64, lr=0.1, epochs=100
# Результат: batch_size=64, lr=0.1, epochs=100, потери на тесте=0.053286
#
# Тестирование: batch_size=64, lr=0.1, epochs=200
# Результат: batch_size=64, lr=0.1, epochs=200, потери на тесте=0.042600
#
# Лучшие параметры для части 1: batch_size=32, lr=0.01, epochs=200 с потерями на тесте: 0.042180
#
# ===== Часть 2: Тестирование конфигураций регуляризации с batch_size=32, lr=0.01, epochs=200 =====
#
# Тестирование: Без Dropout, Без BatchNorm, dropout_rate=0
# Результат: Без Dropout, Без BatchNorm, dropout_rate=0, потери на тесте=0.043427
#
# Тестирование: С BatchNorm, Без Dropout, dropout_rate=0
# Результат: С BatchNorm, Без Dropout, dropout_rate=0, потери на тесте=0.087996
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.1
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.1, потери на тесте=0.045305
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.2
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.2, потери на тесте=0.048622
#
# Тестирование: С Dropout, Без BatchNorm, dropout_rate=0.3
# Результат: С Dropout, Без BatchNorm, dropout_rate=0.3, потери на тесте=0.065170
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.1
# Результат: С Dropout, С BatchNorm, dropout_rate=0.1, потери на тесте=0.047618
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.2
# Результат: С Dropout, С BatchNorm, dropout_rate=0.2, потери на тесте=0.049558
#
# Тестирование: С Dropout, С BatchNorm, dropout_rate=0.3
# Результат: С Dropout, С BatchNorm, dropout_rate=0.3, потери на тесте=0.055092
#
# Лучшие параметры для части 2: config=Без Dropout, Без BatchNorm, dropout_rate=0 с потерями на тесте: 0.043427
# ===== Общие выводы =====
# Функция 1:
#   Лучший размер батча: 64
#   Лучшая скорость обучения (lr): 0.01
#   Лучшее количество эпох: 200
#   Лучшая конфигурация: Без Dropout, Без BatchNorm
#   Лучший dropout rate: 0
#
# Функция 2:
#   Лучший размер батча: 64
#   Лучшая скорость обучения (lr): 0.01
#   Лучшее количество эпох: 100
#   Лучшая конфигурация: С BatchNorm, Без Dropout
#   Лучший dropout rate: 0
#
# Функция 3:
#   Лучший размер батча: 32
#   Лучшая скорость обучения (lr): 0.01
#   Лучшее количество эпох: 200
#   Лучшая конфигурация: Без Dropout, Без BatchNorm
#   Лучший dropout rate: 0
#
# Выводы:
# Модель показала различные оптимальные параметры для каждой функции, при этом batch normalization и dropout влияют на стабильность и точность предсказаний.
# Перебор параметров позволил улучшить производительность сети, особенно для сложных нелинейных зависимостей.
